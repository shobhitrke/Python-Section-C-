# %% [markdown]
# <a href="https://colab.research.google.com/github/shobhitrke/Python-Section-C-/blob/main/Python_Sets%2C_Dictionaries_and_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Sets**

# %%
set_var=set()
print(set_var)
print(type(set_var))
# Out:
# set()
# <class 'set'>

# %%
set_var={"CSE","AIML","Cyber Security"}
print(set_var)
# Out:
# {'Cyber Security', 'CSE', 'AIML'}

# %%
#indexing
set_var['CSE']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fcadda8287d2> in <cell line: 0>()
#       1 #indexing
# ----> 2 set_var['CSE']
#
# TypeError: 'set' object is not subscriptable

# %%
set_var.add("CSA")
set_var.add(1)
print(set_var)
# Out:
# {'CSA', 1, 'CSE', 'AIML', 'Cyber Security'}

# %%
set1={"CSE","AIML","Cyber Security"}
set2={"CSE","AIML","Cyber Security","ME"}

# %%
#Difference
set2.difference(set1)
# Out:
# {'ME'}

# %%
set2
# Out:
# {'AIML', 'CSE', 'Cyber Security', 'ME'}

# %%
set2.difference_update(set1)

# %%
set1
# Out:
# {'AIML', 'CSE', 'Cyber Security'}

# %%
set2.intersection(set1)
# Out:
# {'AIML', 'CSE', 'Cyber Security'}

# %%
set2
# Out:
# {'AIML', 'CSE', 'Cyber Security', 'ME'}

# %%
set2.intersection_update(set1)

# %%
set2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b74a4c664e8b> in <cell line: 0>()
# ----> 1 set2
#
# NameError: name 'set2' is not defined

# %%
dic={}

# %%
#Practical 1
